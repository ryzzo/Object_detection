# %%
import os
import shutil
from object_detection.builders import model_builder
from object_detection.utils import label_map_util
from object_detection.utils import label_map_util
from google.protobuf import text_format
from object_detection.protos import pipeline_pb2
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# ...

# %%
label_map_path = "../../data/label.pbtxt"
label_map_dict = label_map_util.get_label_map_dict(label_map_path)

# %%
from object_detection.utils import label_map_util

category_index = label_map_util.create_category_index_from_labelmap(label_map_path)
print("Categories found:")
for k,v in category_index.items():
    print(f"  {k}: {v['name']}")
# Out:
# Categories found:
#   1: Red
#   2: Blue
#   3: Green

# %%
# !python ../../scripts/create_tf_records.py  \
  --annotation_csv ../../data/annotations.csv \
  --image_dir ../../data/images       \
  --train_record ../../data/train.record  \
  --test_record ../../data/test.record   \
  --label_map ../../data/label.pbtxt \
  --test_split 0.2
# Out:
# Loaded label_map.pbtxt: {'Red': 1, 'Blue': 2, 'Green': 3}
# Wrote ../../data/train.record with 480 examples.
# Wrote ../../data/test.record with 120 examples.
# ✅ TFRecord creation complete.

# %%
MODEL_DIR = '../../training/model_files/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/'
PIPELINE_CONFIG = '../../training/model_files/ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/pipeline.config'
TRAIN_RECORD = '../../data/train.record'
TEST_RECORD = '../../data/test.record'

# %%
model = ''

# %%
# Train the model
# !python ../../scripts/model_main_tf2.py \
  --model_dir={MODEL_DIR} \
  --pipeline_config_path={PIPELINE_CONFIG} \
  --alsologtostderr \
  --log_step_count_steps=1
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl5mutexC1Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# ...

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir ../../training/model_files/ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8/train/ --host 0.0.0.0 --port 6007
# Out:
#       <iframe id="tensorboard-frame-d60ea80f217854da" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d60ea80f217854da");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
