# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir ../../training/model_files/ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8/train/ --host 0.0.0.0 --port 6006
# Out:
#       <iframe id="tensorboard-frame-662222002f73b70f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-662222002f73b70f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
